# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/BasesDeDados/Awari/topyoutube.csv')

# %%
df.head()
# Out:
#           Artist Total Views  100M     Avg
# 0            BTS    27,947.9  63.0   7.370
# 1      Bad Bunny    27,573.4  66.0  14.555
# 2  Justin Bieber    27,399.7  37.0   3.986
# 3     Ed Sheeran    26,894.0  39.0   4.609
# 4   Taylor Swift    24,350.0  38.0   5.716

# %%
df.shape
# Out:
# (1587, 4)

# %%
df.isnull().sum()
# Out:
# Artist           0
# Total Views      0
# 100M           171
# Avg              0
# dtype: int64

# %%
df.fillna("Não informado")
# Out:
#                Artist Total Views           100M     Avg
# 0                 BTS    27,947.9           63.0   7.370
# 1           Bad Bunny    27,573.4           66.0  14.555
# 2       Justin Bieber    27,399.7           37.0   3.986
# 3          Ed Sheeran    26,894.0           39.0   4.609
# 4        Taylor Swift    24,350.0           38.0   5.716
# ...               ...         ...            ...     ...
# 1582  Pietro Lombardi       204.1  Não informado   0.022
# 1583            Duffy       203.2  Não informado   0.020
# 1584          Psirico       201.1            1.0   0.039
# 1585       Alex Clare       200.8  Não informado   0.020
# 1586       The Avener       200.5  Não informado   0.036
#
# [1587 rows x 4 columns]

# %%
df.fillna("Não informado", inplace=True)

# %%
df.dtypes
# Out:
# Artist          object
# Total Views     object
# 100M            object
# Avg            float64
# dtype: object

# %%
df["Total Views"] = df["Total Views"].str.replace(",","")

# %%
df["Total Views"] = df["Total Views"].astype(float)

# %%
df["Total Views"].map(lambda x: x*100000000)
# Out:
# 0       2.794790e+12
# 1       2.757340e+12
# 2       2.739970e+12
# 3       2.689400e+12
# 4       2.435000e+12
#             ...
# 1582    2.041000e+10
# 1583    2.032000e+10
# 1584    2.011000e+10
# 1585    2.008000e+10
# 1586    2.005000e+10
# Name: Total Views, Length: 1587, dtype: float64

# %%
df["Total Views"] = df["Total Views"].map(lambda x: x*100000000)

# %%
df["Total Views"][0]
# Out:
# 2794790000000.0

# %%
df["Avg"].map(lambda x: f"{x:.2f}")
# Out:
# 0        7.37
# 1       14.55
# 2        3.99
# 3        4.61
# 4        5.72
#         ...
# 1582     0.02
# 1583     0.02
# 1584     0.04
# 1585     0.02
# 1586     0.04
# Name: Avg, Length: 1587, dtype: object

# %%
df["Avg"] = df["Avg"].map(lambda x: f"{x:.2f}")

# %%
df["Avg"] = df["Avg"].astype(float)

# %%
df.sort_values(by='Total Views', ascending=False).head(10)
# Out:
#           Artist   Total Views  100M    Avg
# 0            BTS  2.794790e+12  63.0   7.37
# 1      Bad Bunny  2.757340e+12  66.0  14.55
# 2  Justin Bieber  2.739970e+12  37.0   3.99
# 3     Ed Sheeran  2.689400e+12  39.0   4.61
# 4   Taylor Swift  2.435000e+12  38.0   5.72
# 5        Shakira  2.396180e+12  43.0   7.84
# 6     Katy Perry  2.355340e+12  25.0   3.18
# 7          Ozuna  2.252480e+12  49.0   4.93
# 8         Eminem  2.093770e+12  38.0   5.84
# 9  Ariana Grande  2.061850e+12  37.0   3.37

# %%
df.sort_values(by='Artist', ascending=False).head(100)
# Out:
#              Artist   Total Views           100M   Avg
# 1374         Łobuzy  3.965000e+10            2.0  0.11
# 537     İrem Derici  1.717300e+11            3.0  0.32
# 634      Ñengo Flow  1.388800e+11            4.0  0.82
# 1032  Çağatay Akman  7.427000e+10            2.0  0.05
# 350       will.i.am  2.582000e+11            6.0  0.29
# ...             ...           ...            ...   ...
# 516      Via Vallen  1.787500e+11            3.0  0.08
# 1507   Veysel Mutlu  2.774000e+10            1.0  0.03
# 1358         Veysel  4.122000e+10  Não informado  0.06
# 891       Vengaboys  9.348000e+10            3.0  0.34
# 864       Vegedream  9.913000e+10            1.0  0.51
#
# [100 rows x 4 columns]

# %%
df.to_csv('/content/drive/MyDrive/BasesDeDados/Awari/topyoutube_clean.csv', index=False)
